# %%
import os ## gestion des fichiers et dossiers
import numpy as np # calcul numérique et matrices
import pandas as pd # # manipulation de tableaux (DataFrame)
import geopandas as gpd ## données géographiques (shapefile, cartes)
import matplotlib.pyplot as plt # graphiques et cartes

# PySAL : voisinage, autocorr spatiale, régressions spatiales
from libpysal.weights import Queen, KNN
from esda.moran import Moran, Moran_Local
from splot.esda import moran_scatterplot, lisa_cluster

from spreg import OLS, ML_Lag, ML_Error   # OLS / SAR (lag) / SEM (error)

# %%
# !pip install splot
# Out:
# Collecting splot
#   Downloading splot-1.1.7-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: esda in /opt/python/lib/python3.13/site-packages (from splot) (2.8.1)
# Requirement already satisfied: geopandas>=0.9.0 in /opt/python/lib/python3.13/site-packages (from splot) (1.1.2)
# Collecting giddy (from splot)
#   Downloading giddy-2.3.8-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: libpysal in /opt/python/lib/python3.13/site-packages (from splot) (4.14.1)
# Collecting mapclassify (from splot)
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: matplotlib>=3.3.3 in /opt/python/lib/python3.13/site-packages (from splot) (3.10.8)
# Requirement already satisfied: numpy in /opt/python/lib/python3.13/site-packages (from splot) (2.4.2)
# Requirement already satisfied: packaging in /opt/python/lib/python3.13/site-packages (from splot) (26.0)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/python/lib/python3.13/site-packages (from splot) (0.13.2)
# Collecting spreg (from splot)
#   Downloading spreg-1.8.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/python/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (0.12.1)
# Requirement already satisfied: pandas>=2.0.0 in /opt/python/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/python/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /opt/python/lib/python3.13/site-packages (from geopandas>=0.9.0->splot) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib>=3.3.3->splot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/python/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas>=0.9.0->splot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas>=2.0.0->geopandas>=0.9.0->splot) (2025.3)
# Requirement already satisfied: certifi in /opt/python/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas>=0.9.0->splot) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->splot) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.4 in /opt/python/lib/python3.13/site-packages (from esda->splot) (1.8.0)
# Requirement already satisfied: scipy>=1.12 in /opt/python/lib/python3.13/site-packages (from esda->splot) (1.17.1)
# Requirement already satisfied: beautifulsoup4>=4.13.0 in /opt/python/lib/python3.13/site-packages (from libpysal->splot) (4.14.3)
# Requirement already satisfied: jinja2 in /opt/python/lib/python3.13/site-packages (from libpysal->splot) (3.1.6)
# Requirement already satisfied: platformdirs>=3.11.0 in /opt/python/lib/python3.13/site-packages (from libpysal->splot) (4.9.2)
# Requirement already satisfied: requests>=2.32.0 in /opt/python/lib/python3.13/site-packages (from libpysal->splot) (2.32.5)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4>=4.13.0->libpysal->splot) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4>=4.13.0->libpysal->splot) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.32.0->libpysal->splot) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests>=2.32.0->libpysal->splot) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/python/lib/python3.13/site-packages (from requests>=2.32.0->libpysal->splot) (2.6.3)
# Requirement already satisfied: joblib>=1.3.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn>=1.4->esda->splot) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/python/lib/python3.13/site-packages (from scikit-learn>=1.4->esda->splot) (3.6.0)
# Collecting quantecon>=0.8 (from giddy->splot)
#   Downloading quantecon-0.11.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting networkx>=3.2 (from mapclassify->splot)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting numba>=0.49.0 (from quantecon>=0.8->giddy->splot)
#   Downloading numba-0.64.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Collecting sympy (from quantecon>=0.8->giddy->splot)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.49.0->quantecon>=0.8->giddy->splot)
#   Downloading llvmlite-0.46.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/python/lib/python3.13/site-packages (from jinja2->libpysal->splot) (3.0.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->quantecon>=0.8->giddy->splot)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading splot-1.1.7-py3-none-any.whl (39 kB)
# Downloading giddy-2.3.8-py3-none-any.whl (67 kB)
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 469.0 kB/s  0:00:02eta 0:00:01
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 3.1 MB/s  0:00:00 eta 0:00:01
# Downloading quantecon-0.11.0-py3-none-any.whl (327 kB)
# Downloading numba-0.64.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 43.4 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 71.5 MB/s  0:00:00 eta 0:00:01
# Downloading spreg-1.8.5-py3-none-any.whl (396 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 87.6 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 22.5 MB/s  0:00:00
# Installing collected packages: mpmath, sympy, networkx, llvmlite, numba, quantecon, mapclassify, spreg, giddy, splot
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [splot]m 7/10 [spreg]con]
# Successfully installed giddy-2.3.8 llvmlite-0.46.0 mapclassify-2.10.0 mpmath-1.3.0 networkx-3.6.1 numba-0.64.0 quantecon-0.11.0 splot-1.1.7 spreg-1.8.5 sympy-1.14.0
